# %%
#import libraries

from google.colab.patches import cv2_imshow

# %%
import cv2

# %%
#import image 

image = cv2.imread("/content/cat.jpg")

# %%
#resize image with suitable size

img = cv2.resize(image,(600,500))

# %%
#display image

cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=600x500 at 0x7F5721797F50>

# %%
#image in grayscale

img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2_imshow(img_gray)
# Out:
# <PIL.Image.Image image mode=L size=600x500 at 0x7F571FF332D0>

# %%
#image with inverted colours

img_invert = cv2.bitwise_not(img)
cv2_imshow(img_invert)
# Out:
# <PIL.Image.Image image mode=RGB size=600x500 at 0x7F57217A55D0>

# %%
#blurring image

img_smoothing = cv2.GaussianBlur(img_invert, (21,21),sigmaX=0, sigmaY=0)
cv2_imshow(img_smoothing)
# Out:
# <PIL.Image.Image image mode=L size=600x500 at 0x7F5721797FD0>

# %%
def dodgeV2(x, y):
  return cv2.divide(x, 255 - y, scale=256)

# %%
final_img = dodgeV2(img_gray, img_smoothing)
cv2_imshow(final_img)
# Out:
# <PIL.Image.Image image mode=L size=600x500 at 0x7F57217978D0>

# %%
#displaying final image and sketch

cv2_imshow(img)
cv2_imshow(final_img)
# Out:
# <PIL.Image.Image image mode=RGB size=600x500 at 0x7F571FF5B650>
# <PIL.Image.Image image mode=L size=600x500 at 0x7F571FF5B790>
